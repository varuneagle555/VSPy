# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from astropy.io import fits

# %%
file_name = './varfind/varfind.fts'

image_file = fits.open(file_name)
image_data = image_file[0].data

# %%
image_file[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 2048 / length of data axis 1
# NAXIS2  =                 2048 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# BZERO   =                32768 / offset data range to that of unsigned short
# BSCALE  =                    1 / default scaling factor
# DATE-OBS= '2016-11-18T08:02:19' / [ISO 8601] UTC date/time of exposure start
# EXPTIME =   1.20000000000E+002 / [sec] Duration of exposure
# EXPOSURE=   1.20000000000E+002 / [sec] Duration of exposure
# SET-TEMP=  -50.000000000000000 /CCD temperature setpoint in C
# ...

# %%
plt.imshow(image_data, cmap='gray')
plt.colorbar()

plt.show()

# %%
image_file.close()
